# %% [markdown]
# <a href="https://colab.research.google.com/github/Siva-p-11/ML-assiments/blob/main/Summary_AND_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name         : Siva P
# Reg No       : RA2411026010757
# Subject      : Machine Learning
# Subject Code : 21CSC305P
# Section      : AN1

# Practice 2:

# Create a program to display the summary and statistics of the dataset.

# Import required library

import pandas as pd

# Load the Kaggle dataset

df = pd.read_csv("train.csv")

# Display dataset information

print("Dataset Information:")
df.info()

# Display the statistical summary

print("\nStatistical Summary:")
print(df.describe())

# Display the number of samples in each survival category

print("\nSurvival Count:")
print(df["Survived"].value_counts())

# Display the mean of each numerical column

print("\nMean of Each Feature:")
print(df.mean(numeric_only=True))

# Display the median of each numerical column

print("\nMedian of Each Feature:")
print(df.median(numeric_only=True))

# Insights:

# 1. The Titanic dataset contains 891 records.

# 2. The info() function displays column names, data types,
#    non-null values, and memory usage.

# 3. The describe() function provides count, mean, standard deviation,
#    minimum, maximum, and quartile values for numerical features.

# 4. The value_counts() function shows the number of passengers
#    who survived and did not survive.

# 5. The mean() and median() functions help understand the
#    central tendency of numerical features.
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
# Statistical Summary:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...
