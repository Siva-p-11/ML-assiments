# %% [markdown]
# <a href="https://colab.research.google.com/github/Siva-p-11/ML-assiments/blob/main/Load_AND_View.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name         : Siva P
# Reg No       : RA2411026010757
# Subject      : Machine Learning
# Subject Code : 21CSC305P
# Section      : AN1

# Practice 1:
# Devise a program to import, load, and view a dataset.

# Import required library
import pandas as pd

# Load the Kaggle dataset
df = pd.read_csv("titanic.csv")

# Display the first five rows
print("First Five Rows of the Dataset:")
print(df.head())

# Display dataset dimensions
print("\nDataset Shape:")
print(df.shape)

# Display column names
print("\nColumn Names:")
print(df.columns)

# Display dataset information
print("\nDataset Information:")
print(df.info())

# Insights:
# 1. The Titanic dataset contains 891 passenger records.
# 2. The dataset contains 12 columns.
# 3. The head() function displays the first five records.
# 4. The shape attribute returns the number of rows and columns.
# 5. The columns attribute displays all column names.
# 6. Survived is the target variable.
# Out:
# First Five Rows of the Dataset:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
#
# Dataset Shape:
# (418, 12)
#
# Column Names:
# ...
